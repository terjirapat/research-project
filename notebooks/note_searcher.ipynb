# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
from pathlib import Path

sys.path.append(str(Path().resolve().parents[0]))

# %%
from src.utils.loader import load_config

config_path = '../src/config/note_searcher.yaml'
config = load_config(config_path)
# Out:
# 2026-03-19 21:47:19,290 | INFO | Start function 'load_config' at 2026-03-19 21:47:19.290620
# 2026-03-19 21:47:19,291 | INFO | End function 'load_config' at 2026-03-19 21:47:19.291620 | elapsed 0.0011 seconds

# %%
Paper = {
    "paper_id": "paper_001",
    "title": "Demand Forecasting with Machine Learning",
    "year": 2022,
    "source": "journal / arxiv",
}
